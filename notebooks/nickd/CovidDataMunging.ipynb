# %%
import ast
import json
import numpy as np
import pandas as pd

# %%
# load the data
raw_data = pd.read_json("data/coviddata.json")
data = raw_data['values'].tolist()
raw_df = pd.DataFrame(data)

# %%
# some initial exploration
new_cols = df.iloc[:1].values.tolist()[0]
df.columns = new_cols

# handle multiple headers? weird
clean_df = df[2:]
clean_df.head(2)
# Out:
#   Approved Deduped Mod Status           Timestamp  \
# 2        x       x             3/19/2020 11:14:25
# 3        x       x             3/19/2020 14:37:04
#
#   What is the name of the hospital or clinic?  \
# 2                             Swedish Ballard
# 3   Zuckerberg San Francisco General Hospital
#
#                                Final Address  \
# 2     5300 Tallman Ave NW\nSeattle, WA 98107
# 3  1001 Potrero Ave\nSan Francisco, CA 94110
#
#                 Street address for dropoffs?           City State?  \
# 2     5300 Tallman Ave NW\nSeattle, WA 98107        Seattle     WA
# 3  1001 Potrero Ave\nSan Francisco, CA 94110  San Francisco     CA
#
#   Drop off instructions, eg curbside procedure or mailing address ATTN: instructions:  \
# 2  Put in donations bin at registration desk or a...
# 3  For now, call ahead: call the switchboard (628...
#
#    ... Will they accept open boxes/bags? Type of request: Email Address  \
# 2  ...                               Yes
# 3  ...                                No
#
#   Type of organization? CCN / Hospital ID (if applicable)  \
# 2
# 3
#
#   When will you start running out of supplies?  \
# 2
# 3
#
#   Please describe most significant shortages: State?         Lat           Lng
# 2                                                     47.6674625  -122.3795306
# 3                                                     37.7557265  -122.4047381
#
# [2 rows x 21 columns]

# %%
# Get list of all ppe items requested
all_ppe = [ppe.split(',') for ppe in clean_df['What are they accepting?'].values.tolist()]

# %%
# create flat list of all ppe items requests
flatten = lambda l: [item for sublist in l for item in sublist]
flat_ppe = set(flatten(all_ppe))

# %%
# We're gonna break out the PPE items into their own columns and have
# true/false logic for each row corresponding to which PPE items
# they need.

# create dict to store whether each row requested the relevant piece of PPE
store = dict()
for ppe in flat_ppe:
    store[ppe] = []

# count those ppe requestes up
for idx, row in clean_df.iterrows():
    for ppe in store.keys():
        if ppe in row['What are they accepting?']:
            store[ppe].append(True)
        else:
            store[ppe].append(False)

# put it into a df to be joined back with the original dataset            
store_df = pd.DataFrame(store)

# %%
# find the 20 most common items
common_ppe = pd.DataFrame(store_df.sum()).sort_values(0, ascending=False).iloc[:20]
list(common_ppe.index)
# Out:
# ['',
#  'N95s',
#  'Surgical masks',
#  ' Surgical masks',
#  'Face shields',
#  'Gowns',
#  ' Face shields',
#  ' Gown',
#  ' Gowns',
#  ' sanitize',
#  ' sanitizer',
#  'Hand sanitizer',
#  ' Hand sanitizer',
#  ' Safety goggles',
#  'Gloves',
#  ' Gloves',
#  ' Disinfecting wipes',
#  ' Disposable booties',
#  ' Thermometers',
#  ' Surgical Masks']

# %%
# manually create list in order to quickly remove duplicates
most_common_items = ['N95s',
 'Surgical masks',
 'Face shields',
 'Gowns',
 'Hand sanitizer',
 ' Safety goggles',
 'Gloves',
 ' Disinfecting wipes',
 ' Disposable booties',
 ' Thermometers',
 ' Surgical Masks']

# %%
# join the true/false df back with the original dataset
merged_df = df.join(store_df[most_common_items])

# %%
export_df = merged_df.to_csv('data/findthemasksjson_parsed_03272020.csv')

# %% [markdown]
# ## Pulling in Zip Codes (Keyon V did the merge)

# %%
# read in zipcode data that keyon put together
zip_df = pd.read_csv('data/coviddata_metro.csv')

# %%
# fill nans so that we can cast columns as floats
merged_df = merged_df.fillna(np.nan)
zip_df = zip_df.fillna(np.nan)
merged_df[merged_df == 'N/A'] = np.nan
merged_df = merged_df.iloc[2:]

# %%
# we're going to merge on latitude/longitude
# cast latitude/longitude data as a common type (float)
merged_df['Lat'] = merged_df.Lat.apply(float)
merged_df['Lng'] = merged_df.Lng.apply(float)

zip_df['lat'] = zip_df.lat.apply(float)
zip_df['lng'] = zip_df.lng.apply(float)

# merge it up
zip_merged = pd.merge(merged_df, zip_df,  how='left', left_on=['Lat','Lng'], right_on = ['lat','lng'])

# %%
zip_merged
# Out:
#      Approved Deduped Mod Status           Timestamp  \
# 0           x       x             3/19/2020 11:14:25
# 1           x       x             3/19/2020 14:37:04
# 2           x       x             3/19/2020 15:11:30
# 3           x       x             3/19/2020 15:19:46
# 4           x       x             3/19/2020 15:52:02
# ...       ...     ...        ...                 ...
# 1677        x                  Q   3/26/2020 7:25:05
# 1678        x                  Q   3/26/2020 7:28:35
# 1679        x                  Q   3/26/2020 7:36:33
# 1680        x                  Q   3/26/2020 7:28:47
# 1681        x                  Q   3/26/2020 7:31:56
#
#         What is the name of the hospital or clinic?  \
# 0                                   Swedish Ballard
# 1         Zuckerberg San Francisco General Hospital
# 2     Franciscan Women's Health Associates - Burien
# 3                            Moab Regional Hospital
# 4                    Northern Nevada Medical Center
# ...                                             ...
# 1677        Saint Alphonsus Regional Medical Center
# 1678                 Saint Alphonsus Medical Center
# 1679                           CharDonnay Dialysis
# 1680                            Interfaith Medical
# 1681                     Beacon Memorial South Bend
#
#                                     Final Address  \
# 0          5300 Tallman Ave NW\nSeattle, WA 98107
# 1       1001 Potrero Ave\nSan Francisco, CA 94110
# 2               16045 1st Ave S\nBurien, WA 98148
# 3                450 Williams Way\nMoab, UT 84532
# 4            2375 E. Prater Way\nSparks, NV 89431
# ...                                           ...
# 1677            1055 N Curtis Rd\nBoise, ID 83706
# 1678         4300 E Flamingo Ave\nNampa, ID 83687
# 1679  21006 Las Lomas Blvd\nSan Antonio, TX 78258
# 1680        1545 Atlantic Ave\nBrooklyn, NY 11213
# 1681      615 N Michigan St\nSouth Bend, IN 46601
#
#                    Street address for dropoffs?           City State?  \
# 0        5300 Tallman Ave NW\nSeattle, WA 98107        Seattle     WA
# 1     1001 Potrero Ave\nSan Francisco, CA 94110  San Francisco     CA
# 2             16045 1st Ave S\nBurien, WA 98148         Burien     WA
# 3              450 Williams Way\nMoab, UT 84532           Moab     UT
# 4          2375 E. Prater Way\nSparks, NV 89431         Sparks     NV
# ...                                         ...            ...    ...
# 1677                         1055 N. Curtis Rd.          Boise     ID
# 1678                        4300 E Flamingo Ave          Nampa     ID
# 1679                       21006 Las Lomas Blvd   San Antonio      TX
# 1680                      1545 Atlantic Avenue       Brooklyn      NY
# 1681                          615 N Michigan St    South Bend      IN
#
#      Drop off instructions, eg curbside procedure or mailing address ATTN: instructions:  \
# 0     Put in donations bin at registration desk or a...
# 1     For now, call ahead: call the switchboard (628...
# 2     Bring up stairs to the Women's care desk or ca...
# 3                                                   TBD
# 4     Mail to: Alexa Parker, Emergency Dept.- NNMC, ...
# ...                                                 ...
# 1677                     Receiving Dock ATTN: Donations
# 1678      Supply Chain Receiving Dock - ATTN: Donations
# 1679  Administrator's house. Please drop there. Our ...
# 1680                              ATT:Dr. Lawrence Lai
# 1681                                     Att:Vic Wagner
#
#       ... state                                       instructions  \
# 0     ...   NaN                                                NaN
# 1     ...    CA  For now, call ahead: call the switchboard (628...
# 2     ...   NaN                                                NaN
# 3     ...    UT                                                TBD
# 4     ...    NV  Mail to: Alexa Parker, Emergency Dept.- NNMC, ...
# ...   ...   ...                                                ...
# 1677  ...   NaN                                                NaN
# 1678  ...   NaN                                                NaN
# 1679  ...    TX  Administrator's house. Please drop there. Our ...
# 1680  ...   NaN                                                NaN
# 1681  ...    IN                                     Att:Vic Wagner
#
#                                               accepting open_box        lat  \
# 0                                                   NaN      NaN        NaN
# 1                                  N95s, Surgical Masks       No  37.755727
# 2                                                   NaN      NaN        NaN
# 3                  N95s, Surgical Masks, Safety Goggles      Yes  38.575156
# 4     N95s, Surgical Masks, Disposable Booties, Safe...      Yes  39.541116
# ...                                                 ...      ...        ...
# 1677                                                NaN      NaN        NaN
# 1678                                                NaN      NaN        NaN
# 1679  N95s, Face shields, Safety goggles, Gloves, Go...      Yes  29.636998
# 1680                                                NaN      NaN        NaN
# 1681  N95s, Surgical masks, Face shields, Safety gog...      Yes  41.683691
#
#              lng     row  zipcode     FIPS  metro
# 0            NaN     NaN      NaN      NaN    NaN
# 1    -122.404738     4.0  94110.0   6075.0    1.0
# 2            NaN     NaN      NaN      NaN    NaN
# 3    -109.559775     8.0  84532.0  49019.0    0.0
# 4    -119.697360    10.0  89431.0  32031.0    1.0
# ...          ...     ...      ...      ...    ...
# 1677         NaN     NaN      NaN      NaN    NaN
# 1678         NaN     NaN      NaN      NaN    NaN
# 1679  -98.489970  1901.0  78258.0  48029.0    1.0
# 1680         NaN     NaN      NaN      NaN    NaN
# 1681  -86.251976  1903.0  46601.0  18141.0    1.0
#
# [1682 rows x 50 columns]
